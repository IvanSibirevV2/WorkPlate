# %% [markdown]
# - **Аринин Максим Олегович**
#
# Прививка от грипа от колледжа
# - **Валин Даниил Юрьевич**<br/>
#
# прививался от гриппа
# - **Шишкин Михаил Михаилович**<br/>
#
# прививки были, какие не помнит
